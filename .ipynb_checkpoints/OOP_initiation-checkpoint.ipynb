# %%
'''
Create a Vehicle class with max_speed and mileage instance attributes
'''
'''
https://www.w3schools.com/python/python_classes.asp
Create a class named MyClass, with a property named x:

class MyClass:
  x = 5
'''
'''
A refaire avec un init et des paramètre
'''
class Vehicle:
    def __init__(self,max_speed,mileage)
    self.max_speed = max_speed
    self.mileage = mileage

# %%
'''
Create a class, Triangle. Its __init__() method should take self, angle1, angle2, and angle3 as arguments.

Make sure to set these appropriately in the body of the __init__()method.

Create a variable named number_of_sides and set it equal to 3.

Create a method named check_angles.

The sum of a triangle's three angles is It should return True if the sum of self.angle1, self.angle2, 
and self.angle3 is equal 180, and False otherwise.

Create a variable named my_triangle and set it equal to a new instance of your Triangle class.
Pass it three angles that sum to 180 (e.g. 90, 30, 60).

Print out my_triangle.number_of_sides and print out my_triangle.check_angles().
'''

'''
https://www.w3schools.com/python/python_classes.asp
Create a class named Person, use the __init__() function to assign values for name and age:

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)

https://www.google.com/search?q=create+a+method+in+python&oq=create+a+method+&aqs=chrome.7.69i57j0l5j0i22i30i395l4.6640j1j7&sourceid=chrome&ie=UTF-8#kpvalbx=_DE0JYK3eGaGjgweo0LjwDg13
https://stackoverflow.com/questions/60242250/typeerror-init-missing-3-required-positional-arguments/60242291
'''

class Triangle:
    def __init__(self,angle1,angle2,angle3):
        self.angle1 = angle1
        self.angle2 = angle2
        self.angle3 = angle3
        
    def check_angles (self):
        self.result = self.angle1 + self.angle2 + self.angle3
        if self.result == 180 :
            return True
        elif self.result != 180 :
            return False
        return print("Mauvaise manip")

number_of_sides = 3

my_triangle = Triangle(100,30,60)
my_triangle.check_angles ()
print(f"somme des triangles: {my_triangle.result}")
# Out:
# somme des triangles: 190

# %%
'''
Create a Bus child class that inherits from the Vehicle class.

The default fare charge of any vehicle is seating capacity * 100.

If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge.

So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
'''
'''
#https://www.w3schools.com/python/python_inheritance.asp
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

  def welcome(self):
    print("Welcome", self.firstname, self.lastname, "to the class of", self.graduationyear)

x = Student("Mike", "Olsen", 2019)
x.welcome()

output : Welcome Mike Olsen to the class of 2019
'''
class Vehicle:
    def __init__(self,max_speed,mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        #Capacity est définit à vide et sera remplit plus tard dan sle prog, 
        # je peux aussi le mettre en argument de mon init et passer self.capacity = capactity
        self.capacity = []
    
    def fare (self):
        #Default fare est une variable qui utilise les attributs de "init"
        #je la relie aux autres attributs de Vehicule avec le self.default_fare
        self.default_fare = self.capacity * 100
        return self.default_fare
        
        
class Bus (Vehicle) :
    def fare_bus_function (self):
        self.bus_fare = self.fare()*1.1
        print(self.bus_fare)
    

    
my_vehicule = Vehicle (100,0)
my_vehicule.capacity = 35

print("Vehicule fare : " ,my_vehicule.fare())


#My_bus_fare a besoin d'avoir les argument pour définir la classe véhicules
#qu'il a hérité dans la Bus class
my_bus = Bus (100,0)
my_bus.capacity = 35
my_bus.fare_bus_function ()
#print("Bus Fare :",Bus.bus_fare)
# Out:
# Vehicule fare :  3500
# 3850.0000000000005

# %%
'''
Write a Python class to convert an integer to a roman numeral
'''
'''
https://www.w3resource.com/python-exercises/class-exercises/python-class-exercise-1.php
class py_solution:
    def int_to_Roman(self, num):
        val = [
            1000, 900, 500, 400,
            100, 90, 50, 40,
            10, 9, 5, 4,
            1
            ]
        syb = [
            "M", "CM", "D", "CD",
            "C", "XC", "L", "XL",
            "X", "IX", "V", "IV",
            "I"
            ]
        roman_num = ''
        i = 0
        while  num > 0:
            for _ in range(num // val[i]):
                roman_num += syb[i]
                num -= val[i]
            i += 1
        return roman_num


print(py_solution().int_to_Roman(1))
print(py_solution().int_to_Roman(4000))

OU

num_map = [(1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), (100, 'C'), (90, 'XC'),
           (50, 'L'), (40, 'XL'), (10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')]


def num2roman(num):

    roman = ''

    while num > 0:
        for i, r in num_map:
            while num >= i:
                roman += r
                num -= i

    return roman
'''

class Convert:
    
    def __init__(self,number):
        self.number = number
    
    def int_to_Roman(self):
        val = [
            1000, 900, 500, 400,
            100, 90, 50, 40,
            10, 9, 5, 4,
            1
            ]
        syb = [
            "M", "CM", "D", "CD",
            "C", "XC", "L", "XL",
            "X", "IX", "V", "IV",
            "I"
            ]
        roman_num = ''
        i = 0
        while  self.number > 0:
            # "_" est utilisé comme une variable
            for _ in range(self.number // val[i]):
                roman_num += syb[i]
                self.number -= val[i]
            i += 1
        return roman_num


print(Convert(7).int_to_Roman())
#print(Convert().int_to_Roman(4000))
# Out:
# VII

# %%
'''
Write a Python class to get all possible unique subsets from a set of distinct integers. 
Input : [4, 5, 6]
Output : [[], [6], [5], [5, 6], [4], [4, 6], [4, 5], [4, 5, 6]]
'''
'''
https://www.w3resource.com/python-exercises/class-exercises/python-class-exercise-4.php
class py_solution:
    def sub_sets(self, sset):
        return self.subsetsRecur([], sorted(sset))
    
    def subsetsRecur(self, current, sset):
        if sset:
            return self.subsetsRecur(current, sset[1:]) + self.subsetsRecur(current + [sset[0]], sset[1:])
        return [current]

print(py_solution().sub_sets([4,5,6]))
'''

class Sublist :
    def __init__(self,user_list):
        self.user_list = user_list
    def create_sublist (self):
        my_list=[[]]
        for i in self.user_list :
            test = [i]          
            my_list.append(test)
            print(my_list)

    
#my_list1 = [4,5,6]
#my_list2 = []

#for i in my_list1 :
#    test = [i]
#    my_list2.append(test)
#   print(my_list2)


ma_list = Sublist([4,5,6])
ma_list.create_sublist()
# Out:
# [[], [4]]
# [[], [4], [5]]
# [[], [4], [5], [6]]

# %%
'''
Write a Python class named Circle constructed by a radius and two methods

which will compute the area and the perimeter of a circle
'''
class Circle :
    def __init__(self,radius):
        self.radius=radius
    def aire_cercle (self):
        self.aire= 3.14*self.radius*self.radius
        return self.aire
    def perimetre_cercle (self):
        self.perimetre= 2*3.14*self.radius
        return self.perimetre

my_circle = Circle (5)

print("L'aire du cercle est:", my_circle.aire_cercle())
print(m"Le perimetre du cercle est:", my_circle.perimetre_cercle())
# Out:
# 78.5
# 31.400000000000002

# %%
'''
Define a class called Lunch.Its __init__() method should have two arguments:selfanf menu.

Where menu is a string. Add a method called menu_price.It will involve a ifstatement:

if "menu 1" print "Your choice:", menu, "Price 12.00", if "menu 2" print "Your choice:", menu, "Price 13.40",
else print "Error in menu".

To check if it works define: Paul=Lunch("menu 1") and call Paul.menu_price().
'''

class Lunch :
    def __init__ (self,menu):
        self.menu=menu
        
    def menu_price (self):
        if self.menu == 'menu 1':
            print("Your choice:", self.menu, "Price 12.00")
        elif self.menu == 'menu 2':
            print("Your choice:", self.menu, "Price 13.40") 
        else:
            print("Error in menu")

Paul = Lunch ("menu 2")
Paul.menu_price()
# Out:
# Your choice: menu 2 Price 13.40

# %%
'''
Define a class named Shape and its subclass Square. The Square class has an init function which takes a length as argument. 
Both classes have a area function which can print the area of the shape where Shape's area is 0 by default.

Hints:

To override a method in super class, we can define a method with the same name in the super class.

https://realpython.com/python-super/
'''
class Shape:
    def __init__(self, length):
        self.length = length

    def area(self):
        return self.length * self.length
    
    
    
class Square(Shape):
    def __init__(self, length):
        self.length = 0
        super().__init__(length)
        
        
square = Square(4)

square.area()
# Out:
# 16

# %%
'''
Define a class named Rectangle which can be constructed by a length and width. 
The Rectangle class has a method which can compute the area. 

Hints:

Use def methodName(self) to define a method.
'''

class Rectangle :
    def __init__(self, length, width):
        self.length = length
        self.width = width
        
    def area_rectangle (self):
        self.area_result = self.length * self.width
        
rectangle = Rectangle ( 100 , 50 )
rectangle.area_rectangle()
print(rectangle.area_result)
# Out:
# 5000

# %%
'''
Define a Point3D class that inherits from object Inside the Point3D class,
define an __init__() function that accepts self, x, y, and z, and 
assigns these numbers to the member variables self.x,self.y,self.z. 

Define a __repr__() method that returns "(%d, %d, %d)" % (self.x, self.y, self.z). 
This tells Python to represent this object in the following format: (x, y, z). 
Outside the class definition, create a variable named my_point containing a new instance of Point3D 
with x=1, y=2, and z=3. Finally, print my_point.
'''
class Inside :
    def __init__(self, x, y ,z):
        self.x=x
        self.y=y
        self.z=z
        
class Point3D (Inside):
    def __init__(self,x,y,z):
        super().__init__(x,y,z)
        
    def __repr__(self):
        print("(%d, %d, %d)" % (self.x, self.y, self.z))
        
my_point = Point3D(1,2,3)
my_point.__repr__()
# Out:
# (1, 2, 3)

# %%
'''
A very common use case for inheritance is the creation of a custom exception hierarchy.
Because we use the class of an exception to determine whether it should be caught by a particular except block, 
it is useful for us to define custom classes for exceptions which we want to raise in our code. 
Using inheritance in our classes is useful because if an except block catches a particular exception class, 
it will also catch its child classes (because a child class is its parent class). 
That means that we can efficiently write except blocks which handle groups of related exceptions, 
just by arranging them in a logical hierarchy. Our exception classes should inherit from Python’s built-in 
exception classes. They often won’t need to contain any additional attributes or methods.

Write a simple program which loops over a list of user data (tuples containing a username, email and age)
and adds each user to a directory if the user is at least 16 years old. You do not need to store the age.
Write a simple exception hierarchy which defines a different exception for each of these error conditions:

the username is not unique
the age is not a positive integer
the user is under 16
the email address is not valid (a simple check for a username, the @ symbol and a domain name is sufficient)
Raise these exceptions in your program where appropriate.
Whenever an exception occurs, your program should move onto the next set of data in the list. 
Print a different error message for each different kind of exception.

Think about where else it would be a good idea to use a custom class, and what kind of collection type would 
be most appropriate for your directory.

You can consider an email address to be valid if it contains one @ symbol and has a non-empty username and domain
name – you don’t need to check for valid characters. You can assume that the age is already an integer value.
'''

'''
https://beginnersbook.com/2018/02/python-tuple/
https://stackoverflow.com/questions/5188792/how-to-check-a-string-for-specific-characters
https://python-textbok.readthedocs.io/en/1.0/Object_Oriented_Programming.html
https://kaijento.github.io/2017/03/15/modifying-index-in-a-python-for-loop/
for i in range(5):
    if i == 2:
        continue
    print(i)
'''
#Définition d'un tuple dans un tuple pour les informations
my_data = (("Jojo", "play@boy@sublime.com", -5),
           ("cindy", "@tiktokeuse.com", 14),
          ("Jonnhy", "blaireau@", 26),
           ("Sara", "kebab@star.com", 19),
          ("Sara", "gourou@dubled.com", 35))

#stockage des username pour controler s'il existent
user_name_list=[]

class User : 
    def __init__(self, username, email, age):
        self.username = username
        self.email = email
        self.age = age
    
    def my_user_info (self):
        print (f"name:{self.username}, email:{self.email}, age:{self.age}")
        
class Age_specifications(User):
    '''
    def __init__(self,age):
        self.age=age
        super().__init__(self, username, email, age)
    '''
    def under_16 (self):
        if (self.age < 16) and ( self.age >= 0) :
            print ("wrong age : coller la petite")
            return True
        else:
            return False
            
    def negative_integer (self):
        if self.age<0:
            print(f"wrong age, négative number : {self.age}")
            return True
        else:
            return False
        
class Email_specifications(User):
    
    def email_verif (self):
        self.arobase_count=0
        
        #check si l'adresse a le symbole arobase
        for characters in self.email :
            if characters == '@':
                self.arobase_count += 1
                
        if self.arobase_count != 1 :
            print("Missing @ charater or too much @ characters")
            return True
        
        #test s'il y a un caractère, un nombre ou une lettre au début de la la string adresse
        if (self.email[0].isalpha()==False) and (self.email[0].isdigit()==False) :
            print("Wrong address: mets des caractères valides au début wesh")
            return True
        
        if (self.email[-1].isalpha()==False) and (self.email[-1].isdigit()==False) :
            print("Wrong address :mets des caractères valides à la fin wesh")
            return True
        
        else:
            return False
            
class Username_specifications(User):
    
    def unique_username (self):
        if self.username not in user_name_list:
            user_name_list.append(self.username)
            return False
        else:
            print(f"Username {self.username} already exists")
            return True
        
        
for user_local in my_data :
    
    local_username = user_local[0]
    local_email = user_local[1]
    local_name = user_local[2]
        
    print("\n")
    
    #J'initialise  ma classe fille avec les besoins de la classe mère
    user_info = Age_specifications(local_username,local_email,local_name)
    
    #J'utilise une fonction définie dans la classe mère
    user_info.my_user_info()
    
    #avec le continue, s'il y a une erreur avec l'age , je ne check pas les autres données
    if user_info.under_16() == True: continue
         
    if user_info.negative_integer() == True: continue
    
              
    user_info = Email_specifications(local_username,local_email,local_name)
    if user_info.email_verif() == True: continue
    
    
    user_info = Username_specifications(local_username,local_email,local_name)
    if user_info.unique_username() == True: continue
        
    print("User infos valid")
# Out:
# name:Jojo, email:play@boy@sublime.com, age:-5
# wrong age, négative number : -5
#
#
# name:cindy, email:@tiktokeuse.com, age:14
# wrong age : coller la petite
#
#
# name:Jonnhy, email:blaireau@, age:26
# Wrong address :mets des caractères valides à la fin wesh
#
#
# name:Sara, email:kebab@star.com, age:19
# User infos valid
#
#
# name:Sara, email:gourou@dubled.com, age:35
# Username Sara already exists
